# %% [markdown]
# ### Переменные и комментарии

# %%
variable = 10

# %%
variable
# Out:
# 10

# %%
print(variable)
# Out:
# 10

# %%
# print(variable)

# %%
variable = 15

# %%
variable
# Out:
# 15

# %%
variable = 'string_Sergey'

# %%
variable
# Out:
# 'string_Sergey'

# %%
print(variable)
# Out:
# string_Sergey

# %%
var1 = 1000000
var2 = 1_000_000  # Для лучшего восприятия

# %%
var1, var2
# Out:
# (1000000, 1000000)

# %%
var3 = 0.01
var4 = .01

# %%
var3 == var4
# Out:
# True

# %%
from tqdm import tqdm

# %%
x = 0
for i in tqdm(range(1, 1_000_000_003)):
    if i % 3 == 0:
        if i % 10 != 4 and i % 10 != 7:
           x += i
# Out:
# 100%|██████████| 1000000002/1000000002 [04:24<00:00, 3773908.63it/s]

# %%
x
# Out:
# 133333334466666672

# %%
y = 133333333466666670

# %%
z = 133333334466666672

# %%
def ap(x1, xn, n):
    return (x1+xn)*n//2

print(ap(3, 1000000002, 333333334) - ap(24, 999999984, 33333333) - ap(27, 999999987, 33333333))
# Out:
# 133333334466666672

# %%
with open(file='test_input_file_1.txt') as file:
    for line in file:
        print(line)
# Out:
# +    -8747    7196
#
# //    8687    8854
#
# *    -9061    5499
#
# %    8426    8108
#
# *    -7823    -8768
#
# +    -4641    4275
#
# -    7053    8073
#
# //    9944    7716
#
# //    552    4800
#
# %    5927    5972
#
# **    86    13
#
# *    -1865    -2149
#
# %    4609    355
#
# +    1410    -7494
#
# //    5701    4313
#
# %    5510    6780
#
# +    3554    3788
#
# -    -2461    237
#
# //    9785    6301
#
# %    4080    3708
#
# -    2325    2866
#
# *    5179    5876
#
# +    8970    6724
#
# **    25    12
#
# *    2391    7041
#
# //    2086    4883
#
# **    14    13
#
# **    67    86
#
# *    -9949    5297
#
# %    3614    2549
#
# %    451    2711
#
# //    4161    6953
#
# +    -370    2993
#
# //    227    8777
#
# **    25    35
#
# +    7670    -5460
#
# %    6149    8075
#
# +    -9068    -3074
#
# **    8    27
#
# %    1459    1558
#
# //    2407    3019
#
# //    1409    6484
#
# %    1286    2995
#
# %    4063    363
#
# *    -381    -7315
#
# ...
